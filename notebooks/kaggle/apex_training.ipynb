# %% [markdown]
# # APEX-1 Kaggle training
# Status: **EXPERIMENTAL / REQUIRES_KAGGLE**. Enable a Kaggle GPU before running.

# %%
# %pip install -e '.[dev,model]'
from apex.compute import KaggleProvider

status = KaggleProvider().require_training_runtime()
status.to_dict()

# %%
# Set this to a licensed text file attached as a Kaggle Dataset.
DATASET = '/kaggle/input/replace-me/train.txt'
COMMAND = (
    'python scripts/kaggle/train.py '
    f'--dataset {DATASET} '
    '--output /kaggle/working/apex-artifacts/run '
    '--steps 10 --dataset-license unknown'
)
# !$COMMAND
